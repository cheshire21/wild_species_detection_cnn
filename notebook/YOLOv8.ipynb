# %% [markdown]
# #Yolov8
# # Install library

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.1/166.8 GB disk)

# %% [markdown]
# Montar drive

# %% [markdown]
# Connect with your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. Train
# First add the custom data file and dataset on Colab file and then train the yolov8x model

# %%
import time
inicio = time.time()
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8x.pt data=/content/custom_data.yaml epochs=70 imgsz=640 batch=16 project=/content/results name=yolov8x
fin = time.time()
#Tiempo en minutos
tiempo_ejecucion_yolov8x=(fin-inicio)/60
print("El tiempo de ejecución es de: ",tiempo_ejecucion_yolov8x)
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# First add the custom data file and dataset on Colab file and then train the yolov8l model

# %%
import time
inicio = time.time()
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8l.pt data=/content/custom_data.yaml epochs=70 imgsz=640 batch=16 project=/content/results name=yolov8l
fin = time.time()
#Tiempo en minutos
tiempo_ejecucion_yolov8l=(fin-inicio)/60
print("El tiempo de ejecución es de: ",tiempo_ejecucion_yolov8l)
# Out:
# ...
# 100% 83.7M/83.7M [00:05<00:00, 15.2MB/s]
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Test the yolov8l model with a video

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/results/yolov8l/weights/best.pt source=/content/drive/MyDrive/UNSA/nuevo-video.mp4
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43611234 parameters, 0 gradients
#
# video 1/1 (1/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 62.0ms
# video 1/1 (2/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 40.9ms
# video 1/1 (3/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 40.7ms
# video 1/1 (4/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 37.5ms
# video 1/1 (5/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 32.4ms
# video 1/1 (6/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 (no detections), 32.4ms
# video 1/1 (7/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 (no detections), 32.4ms
# video 1/1 (8/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 (no detections), 24.6ms
# ...

# %% [markdown]
# ## Download the output video

# %%
# !cp /content/runs/detect/predict/nuevo-video.mp4 /content/drive/MyDrive/UNSA/vi/

# %% [markdown]
# # Test the yolov8x4 model using a video

# %%
# !yolo predict model=/content/results/yolov8x4/weights/best.pt source=/content/drive/MyDrive/UNSA/nuevo-video.mp4
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68129346 parameters, 0 gradients
#
# video 1/1 (1/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 64.1ms
# video 1/1 (2/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 52.6ms
# video 1/1 (3/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 52.5ms
# video 1/1 (4/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 41.8ms
# video 1/1 (5/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 41.9ms
# video 1/1 (6/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 41.8ms
# video 1/1 (7/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 31.0ms
# video 1/1 (8/3889) /content/drive/MyDrive/UNSA/nuevo-video.mp4: 384x640 1 Opisthocomus_hoazin, 30.4ms
# ...

# %% [markdown]
# ## Download the output video

# %%
# !cp /content/runs/detect/predict/nuevo-video.mp4 /content/drive/MyDrive/UNSA/vi/

# %% [markdown]
# ## Zip results folder of models

# %%
# !zip -r yolov8x.zip /content/results/yolov8x4
# !zip -r yolov8l.zip /content/results/yolov8l
# Out:
#   adding: content/results/yolov8x4/ (stored 0%)
#   adding: content/results/yolov8x4/labels.jpg (deflated 25%)
#   adding: content/results/yolov8x4/train_batch2.jpg (deflated 3%)
#   adding: content/results/yolov8x4/train_batch0.jpg (deflated 3%)
#   adding: content/results/yolov8x4/train_batch1.jpg (deflated 3%)
#   adding: content/results/yolov8x4/val_batch1_labels.jpg (deflated 8%)
#   adding: content/results/yolov8x4/labels_correlogram.jpg (deflated 41%)
#   adding: content/results/yolov8x4/results.csv (deflated 85%)
#   adding: content/results/yolov8x4/val_batch0_pred.jpg (deflated 6%)
#   adding: content/results/yolov8x4/args.yaml (deflated 52%)
#   adding: content/results/yolov8x4/PR_curve.png (deflated 11%)
#   adding: content/results/yolov8x4/F1_curve.png (deflated 7%)
#   adding: content/results/yolov8x4/events.out.tfevents.1687657326.83ae3fc33bcd.5169.0 (deflated 72%)
#   adding: content/results/yolov8x4/confusion_matrix_normalized.png (deflated 21%)
# ...

# %% [markdown]
# ## Copy zip files to drive

# %%
# !cp /content/yolov8x.zip /content/drive/MyDrive/UNSA/vi/

# %%
# !cp /content/yolov8l.zip /content/drive/MyDrive/UNSA/vi/
